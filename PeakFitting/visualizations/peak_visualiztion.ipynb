# %%
import sys
sys.path.append('..')
from fitting import FindPeaks

# %%
# !pwd
# Out:
# /home/eric/Work/materials-dept/HTCeramics/PeakFitting/visualizations

# %%
import pandas as pd
data = pd.read_csv('../xrdData/polyxtal.csv')
two_theta = data['Angle']
intensity = data['Intensity']

peak_finder = FindPeaks()
peak_finder.fit(two_theta, intensity)
peaks = peak_finder.find_peaks()
print('_')

import matplotlib.pyplot as plt
# %matplotlib notebook
fig, ax = plt.subplots()
ax.scatter(two_theta, intensity, s=4)

for i,_ in peaks:
    ax.axvline(x=two_theta[i], c='black', linestyle='dotted')

plt.show()
# Out:
# _
# <img src="data:image/png;base64,..." width="639.2666666666667">
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-10a6fa0dac62> in <module>
#      14 ax.scatter(two_theta, intensity, s=4)
#      15
# ---> 16 for i,_ in peaks:
#      17     ax.axvline(x=two_theta[i], c='black', linestyle='dotted')
#      18
#
# ValueError: too many values to unpack (expected 2)
